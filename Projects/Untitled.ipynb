# %%
from fastai.vision import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c0e76450f370> in <module>
# ----> 1 from fastai.vision import *
#
# ~/.virtualenvs/fastai/lib/python3.7/site-packages/fastai/vision/__init__.py in <module>
# ----> 1 from .. import basics
#       2 from ..basics import *
#       3 from .learner import *
#       4 from .image import *
#       5 from .data import *
#
# ~/.virtualenvs/fastai/lib/python3.7/site-packages/fastai/basics.py in <module>
# ----> 1 from .basic_train import *
#       2 from .callback import *
#       3 from .core import *
#       4 from .basic_data import *
#       5 from .data_block import *
#
# ~/.virtualenvs/fastai/lib/python3.7/site-packages/fastai/basic_train.py in <module>
#       1 "Provides basic training and validation with `Learner`"
# ----> 2 from .torch_core import *
#       3 from .basic_data import *
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True
