# %%
from fastai.vision import *

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
path = untar_data(URLs.MNIST_SAMPLE)
path
# Out:
# PosixPath('/home/jakkrit/.fastai/data/mnist_sample')

# %%
data = ImageDataBunch.from_folder(path)

learn = cnn_learner(data, models.resnet18, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/jakkrit/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:03<00:00, 12.2MB/s]

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.225313</td>
#       <td>0.125144</td>
#       <td>0.954858</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.115398</td>
#       <td>0.077981</td>
#       <td>0.973013</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.081204</td>
#       <td>0.067320</td>
#       <td>0.975957</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(6,6))

# %%
interp.plot_confusion_matrix()

# %%
img = learn.data.train_ds[0][0]
